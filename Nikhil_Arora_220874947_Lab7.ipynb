# %% [markdown]
# # Lab 7
#
# ## Nikhil Arora
#
# ## 220874947

# %% [markdown]
# ## Task 1 - 4:

# %%
######################################
# EECS1015 - Fall 2023
# Lab 07
#####################################
import random

def print_student_info():
    print("\nStudent Information:")
    print("Name: Nikhil Arora")
    print("Student ID: 220874947")

def task0():
    print_student_info()

# Functions for task 1
# Write the function average_num() outside your task1() function.
def average_num(*nums):
    if not nums:
        return 0
    return sum(nums) / len(nums)

def task1():
    while True:
        try:
            numCount = int(input("Input 4 or 5 numbers? "))
            if numCount not in [4, 5]:
                print("Please enter either 4 or 5.")
                continue
                
            numString = input(f"Input {numCount} numbers [x1, x2, x3, x4" + (', x5' if numCount == 5 else '') + "] : ")
            numList = [int(num) for num in numString.split(',')]
            
            if numCount == 4:
                result = average_num(*numList[:4])
            else:
                result = average_num(*numList)
                
            print(f"Average is {result:.2f}")
        except ValueError:
            print("Invalid input. Please enter integers separated by commas.")
            
        tryAgain = input("Try again? ")
        if tryAgain.lower() != 'y':
            break
            
# Task 2
# Write function build_stock_dict() here.

def string_to_stock_dict(astring):
    stockDict = {}

    stockInfoList = astring.split()

    for stockInfo in stockInfoList:
        stockData = stockInfo.split(':')
        symbol = stockData[2]
        price = float(stockData[1])
        companyName = stockData[0]

        stockDict[symbol] = [companyName, price]

    return stockDict

# This function is provided for you.
def print_stock_dict(stockDict):
    keys = list(stockDict.keys())
    print("{:10s} {:6s}  {}".format("Symbol", "Price", "Company Name"))
    print("-"*31)
    for k in keys:
        print(f"{k:7s} {stockDict[k][1]:8.2f}   {stockDict[k][0]}") 
        #stockDict[k][1]
        # ^^^^^^^^^^^^^    <- this gets the list for the key k
        #              ^^^ <- this retrieves item [1] in the list (price of stock)
        #
    print() # <- an extra empty print to make it look nice


def task2():
    stockDict1 = {"SNAP": ["Snap", 10.08], "PINS": ["Pinterest", 29.40], "GOOG": ["Google", 96.58]}
    stock_list_string = "Apple:155.74:AAPL Tesla:228.52:TSLA Ford:13.26:F Microsoft:9.12:MSFT Shopify:34.19:SHOP"
    print_stock_dict(stockDict1)
    #uncomment code for task4
    stock_dict2 = string_to_stock_dict(stock_list_string)
    print_stock_dict(stock_dict2)

def create_rand_list():
    numOfElement = random.randint(5, 15)
    minValue = random.randint(5, 10)
    maxValue = random.randint(20, 50)
    
    randomList = [random.randint(minValue, maxValue) for _ in range(numOfElement)]
    return randomList

def print_list(a_list):
    if not a_list:
        print("---list---\n(empty)")
    else:
        print("---list---")
        for item in a_list:
            print(f"({item})->", end="")
        print("(end)")

def delete_item_from_list(a_list, item):
    if item not in a_list:
        return -1

    index = a_list.index(item)
    del a_list[index]
    return index
    
# Task 3 functions create_rand_list(), delete_list_item(), print_list() here ourside task3()
def task3():
    randomList = create_rand_list()

    while True:

        print_list(randomList)

        itemToDelete = int(input("Item to delete: "))

        deleteResult = delete_item_from_list(randomList, itemToDelete)

        if deleteResult != -1:
            print(f"Item {itemToDelete} successfully deleted at position {deleteResult}.")
        else:
            print(f"Item {itemToDelete} could not be deleted.")

        deleteAnother = input("Delete item [Y/N]? ").lower()
        if deleteAnother != 'y':
            break

# Task 4
# Write functions print_image and uncompress_rle_image() here
def print_image(image):
    for line in image:
        print(line)

def uncompress_rle_image(rle_image):
    text_image = []
    for rle_line in rle_image:
        text_line = ""
        for run in rle_line:
            text_line += run[0] * run[1]
        text_image.append(text_line)
    return text_image

def task4():
    rle_image1 = [[(5, '-')], [(2, ' '), (1, '|')], [(2, ' '), (1, '|')], [(1, ' '), (3, '-')]]
    rle_image2 = [[(9, ' '), (1, '.'), (1, '8'), (1, '.'), (1, ' ')], [(9, ' '), (3, '8'), (1, ' ')], [(9, ' '), (3, '8'), (1, 'l')],
     [(8, ' '), (1, 'j'), (4, '8'), (1, '.')], [(7, ' '), (1, '.'), (6, '8'), (1, '.')],
     [(6, ' '), (1, '.'), (8, '8'), (1, '.')], [(4, ' '), (1, '.'), (1, 'd'), (10, '8'), (1, 'b'), (1, '.'), (1, ' ')],
     [(2, ' '), (1, '.'), (1, 'd'), (14, '8'), (1, 'b'), (1, '.')], [(1, ' '), (1, '.'), (18, '8'), (1, 'b'), (1, '.')],
     [(1, '.'), (21, '8')], [(22, '8')], [(3, '8'), (1, 'P'), (2, '"'), (1, '4'), (3, '8')],
     [(1, '`'), (1, 'P'), (1, "'"), (5, ' '), (1, '.'), (4, ' '), (1, '.'), (5, ' '), (1, '`'), (1, 'q'), (1, "'")],
     [(1, ' '), (1, '`'), (1, '-'), (2, '.'), (4, '_'), (1, ':'), (2, ' '), (1, ':'), (4, '_'), (2, '.'), (1, '-'),
      (1, "'"), (1, ' ')], [(9, ' '), (1, ':'), (2, ' '), (1, ':')], [(9, ' '), (1, ':'), (2, ' '), (1, ':')],
     [(9, ' '), (1, ':'), (2, ' '), (1, ':')], [(9, ' '), (1, ':'), (2, ' '), (1, ':')],
     [(9, ' '), (1, ':'), (2, ' '), (1, ':')],
     [(7, ' '), (1, '\\'), (1, '('), (1, '/'), (1, '\\'), (1, ')'), (1, '\\'), (1, '/'), (1, ' '), (1, 'm'), (1, 'h')]]
    rle_image3 = [[(52, '.')], [(52, '.')], [(25, '.'), (1, '/'), (1, '\\'), (25, '.')], [(18, '.'), (6, '_'), (1, '/'), (2, '_'), (1, '\\'), (7, '_'), (17, '.')], [(18, '.'), (2, '|'), (13, '-'), (2, '|'), (17, '.')], [(18, '.'), (2, '|'), (13, ' '), (2, '|'), (17, '.')], [(18, '.'), (2, '|'), (4, ' '), (1, '\\'), (3, '|'), (1, '/'), (4, ' '), (2, '|'), (17, '.')], [(18, '.'), (2, '|'), (3, ' '), (1, '['), (1, ' '), (1, '@'), (1, '-'), (1, '@'), (1, ' '), (1, ']'), (3, ' '), (2, '|'), (17, '.')], [(18, '.'), (2, '|'), (4, ' '), (1, '('), (1, ' '), (1, '.'), (1, ' '), (1, ')'), (4, ' '), (2, '|'), (7, '.'), (7, ' '), (3, '.')], [(18, '.'), (2, '|'), (4, ' '), (1, '_'), (1, '('), (1, 'O'), (1, ')'), (1, '_'), (4, ' '), (2, '|'), (7, '.'), (1, '|'), (1, 'E'), (1, 'X'), (1, 'I'), (1, 'T'), (1, ' '), (1, '|'), (3, '.')], [(18, '.'), (2, '|'), (3, ' '), (1, '/'), (1, ' '), (1, '>'), (1, '='), (1, '<'), (1, ' '), (1, '\\'), (3, ' '), (2, '|'), (7, '.'), (1, '|'), (2, '='), (2, '>'), (1, ' '), (1, '|'), (3, '.')], [(18, '.'), (2, '|'), (2, '_'), (1, '/'), (1, '_'), (1, '|'), (1, '_'), (1, ':'), (1, '_'), (1, '|'), (1, '_'), (1, '\\'), (2, '_'), (2, '|'), (17, '.')], [(18, '.'), (17, '-'), (17, '.')], [(52, '.')], [(52, '.')]]
    
    # uncomment code for task4
    print("\t\tImage 1\n")
    image1 = uncompress_rle_image(rle_image1)
    print_image(image1)
    print("\t\tImage 2\n")
    image2 = uncompress_rle_image(rle_image2)
    print_image(image2)
    print("\t\tImage 3\n")
    image3 = uncompress_rle_image(rle_image3)
    print_image(image3)

def main():
    task0()
    print("\n--- Task 1: Average numbers ---")
    task1()
    print("\n--- Task 2: Text to dictionary---")
    task2()
    print("\n--- Task 3: Deleting from list---")
    task3()
    print("\n--- Task 4: RLE decoding  ---")
    task4()

    input("Press enter to end lab 7.")

if __name__ == '__main__':
    main()
# Out:
# Student Information:
# Name: Nikhil Arora
# Student ID: 220874947
#
# --- Task 1: Average numbers ---
# Input 4 or 5 numbers? 4
# Input 4 numbers [x1, x2, x3, x4] : 1, 2, 3, 4
# Average is 2.50
# Try again? n
#
# --- Task 2: Text to dictionary---
# Symbol     Price   Company Name
# -------------------------------
# SNAP       10.08   Snap
# PINS       29.40   Pinterest
# GOOG       96.58   Google
#
# Symbol     Price   Company Name
# -------------------------------
# AAPL      155.74   Apple
# TSLA      228.52   Tesla
# F          13.26   Ford
# MSFT        9.12   Microsoft
# SHOP       34.19   Shopify
#
#
# --- Task 3: Deleting from list---
# ---list---
# (35)->(42)->(36)->(33)->(24)->(9)->(39)->(25)->(21)->(21)->(9)->(26)->(end)
# Item to delete: 26
# Item 26 successfully deleted at position 11.
# Delete item [Y/N]? n
#
# --- Task 4: RLE decoding  ---
# 		Image 1
#
# -----
#   |
#   |
#  ---
# 		Image 2
#
#          .8.
#          888
#          888l
#         j8888.
#        .888888.
#       .88888888.
#     .d8888888888b.
#   .d88888888888888b.
#  .888888888888888888b.
# .888888888888888888888
# 8888888888888888888888
# 888P""4888
# `P'     .    .     `q'
#  `-..____:  :____..-'
#          :  :
#          :  :
#          :  :
#          :  :
#          :  :
#        \(/\)\/ mh
# 		Image 3
#
# ....................................................
# ....................................................
# ........................./\.........................
# ..................______/__\_______.................
# ..................||-------------||.................
# ..................||             ||.................
# ..................||    \|||/    ||.................
# ..................||   [ @-@ ]   ||.................
# ..................||    ( . )    ||.......       ...
# ..................||    _(O)_    ||.......|EXIT |...
# ..................||   / >=< \   ||.......|==>> |...
# ..................||__/_|_:_|_\__||.................
# ..................-----------------.................
# ....................................................
# ....................................................
# Press enter to end lab 7.
